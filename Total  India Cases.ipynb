# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
sns.set(color_codes=True)
# %matplotlib inline          
data=pd.read_csv('Total india cases.csv')
data
# Out:
#                           State   Cases   Recovered  Deaths
# 0   Andaman and Nicobar Islands     4389       4163      60
# 1                Andhra Pradesh   833208     805026    6744
# 2             Arunachal Pradesh    15160      13472      43
# 3                         Assam   207741     198697     934
# 4                         Bihar   218605     211398    1113
# 5                    Chandigarh    14702      13802     229
# 6                  Chhattisgarh   194499     169410    2316
# 7            Dadar Nagar Haveli     3262       3228       2
# 8                         Delhi   409938     365866    6703
# 9                           Goa    44372      41611     626
# 10                      Gujarat   176446     160333    3737
# 11                      Haryana   174082     158136    1836
# 12             Himachal Pradesh    23365      19579     355
# 13                        J & K    96700      89254    1511
# 14                    Jharkhand   103188      97480     894
# ...

# %% [markdown]
# ### Find out All  NULL Values

# %%
data.isnull()
# Out:
#     State  Cases   Recovered  Deaths
# 0   False   False      False   False
# 1   False   False      False   False
# 2   False   False      False   False
# 3   False   False      False   False
# 4   False   False      False   False
# 5   False   False      False   False
# 6   False   False      False   False
# 7   False   False      False   False
# 8   False   False      False   False
# 9   False   False      False   False
# 10  False   False      False   False
# 11  False   False      False   False
# 12  False   False      False   False
# 13  False   False      False   False
# 14  False   False      False   False
# 15  False   False      False   False
# 16  False   False      False   False
# 17  False   False      False   False
# 18  False   False      False   False
# 19  False   False      False   False
# 20  False   False      False   False
# 21  False   False      False   False
# 22  False   False      False   False
# 23  False   False      False   False
# ...

# %%
m=data.head()
m
# Out:
#                          State  Cases   Recovered  Deaths
# 0  Andaman and Nicobar Islands    4389       4163      60
# 1               Andhra Pradesh  833208     805026    6744
# 2            Arunachal Pradesh   15160      13472      43
# 3                        Assam  207741     198697     934
# 4                        Bihar  218605     211398    1113

# %% [markdown]
# ## distribution plot(distplot)
#
# ### Represents the overall distribution of continuous data variables..
# ### And Used to depict the distplot with different variation in it..

# %%
sns.distplot(data['Deaths'])
plt.show()
# Out:
# c:\users\nikhil\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Pairwise Relationship(pairplot)
# ####  For multiple pairwise bivariate distribution in a dataset..

# %%
sns.pairplot(data)
plt.show()

# %% [markdown]
#  ### Stripplot

# %%
fig_dims=(10,5)
fig, ax=plt.subplots(figsize=fig_dims)

sns.stripplot(a['State'],a['Recovered'],ax=ax)
# Out:
# c:\users\nikhil\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='State', ylabel='Recovered'>

# %%
b=data[data['Recovered']>400000]
b
# Out:
#              State   Cases   Recovered  Deaths
# 1   Andhra Pradesh   833208     805026    6744
# 15       Karnataka   835773     788780   11281
# 19      Maharashta  1698198    1540005   44548
# 29      Tamil Nadu   734429     704031   11244
# 32              UP   489502     459722    7104

# %% [markdown]
# ### pointplot

# %%
sns.pointplot(b['State'],b['Deaths'])

plt.show()
# Out:
# c:\users\nikhil\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Barplot

# %%
fig_dims=(50,15)
fig, ax=plt.subplots(figsize=fig_dims)
sns.barplot(data['State'],data['Deaths'],ax=ax)
# Out:
# <AxesSubplot:xlabel='State', ylabel='Deaths'>

# %% [markdown]
# ### Boxplot

# %%
sns.boxplot(b['Deaths'],b['State'])
# Out:
# c:\users\nikhil\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Deaths', ylabel='State'>

# %%
fig_dims=(40,15)
fig, ax=plt.subplots(figsize=fig_dims)
sns.pointplot(data['State'],data['Recovered'],ax=ax)
plt.show()
# Out:
# c:\users\nikhil\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Scatter plot

# %%
fig_dims=(30,15)
fig, ax=plt.subplots(figsize=fig_dims)
sns.scatterplot(data=data,x='Deaths',y='State',ax=ax,palette='deep',hue='Deaths')
# Out:
# <AxesSubplot:xlabel='Deaths', ylabel='State'>
